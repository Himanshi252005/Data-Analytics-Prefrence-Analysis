# %%
import pandas as pd
import folium
from datetime import datetime
import pytz

# %%
df = pd.read_csv("job_descriptions.csv")

# %%
df['Salary_clean'] = (
    df['Salary Range']
    .astype(str)
    .str.replace('[^0-9]', '', regex=True)
    .astype(float)
)

# %%
strict_df = df[
    (df['Qualifications'].isin(['B.Tech', 'M.Tech', 'PhD'])) &
    (df['Work Type'] == 'Full-Time') &
    (df['Country'].str.contains('Africa', case=False, na=False)) &
    (df['Job Title'].str.startswith('D', na=False)) &
    (df['Preference'] == 'Male') &
    (df['Company Size'] > 80000) &
    (df['Contact Person'].str.startswith('A', na=False)) &
    (df['Job Portal'] == 'Indeed') &
    (df['Salary_clean'] > 20000)
]

# %%
fallback_df = df[
    (df['Qualifications'].isin(['B.Tech', 'M.Tech', 'PhD'])) &
    (df['Work Type'] == 'Full-Time') &
    (df['Country'].str.contains('Africa', case=False, na=False))
]

# %%
df['latitude'] = pd.to_numeric(df['latitude'], errors='coerce')
df['longitude'] = pd.to_numeric(df['longitude'], errors='coerce')

df = df.dropna(subset=['latitude', 'longitude'])

# %%
map_df = df[
    (df['Country'].str.contains('Africa', case=False, na=False))
].head(20)

# %%
map_df[['latitude', 'longitude']].head()
# Out:
#      latitude  longitude
# 76   -30.5595    22.9375
# 134  -30.5595    22.9375
# 153    6.6111    20.9394
# 215  -30.5595    22.9375
# 230  -30.5595    22.9375

# %%
m = folium.Map(location=[0, 20], zoom_start=3)

for _, row in map_df.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=f"""
        <b>Company:</b> {row['Company']}<br>
        <b>Job Title:</b> {row['Job Title']}<br>
        <b>Qualification:</b> {row['Qualifications']}
        """,
        tooltip="Click me"
    ).add_to(m)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf64a78951cae36e405eb531ba4d4732 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf64a78951cae36e405eb531ba4d4732&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf64a78951cae36e405eb531ba4d4732 = L.map(
#                 &quot;map_cf64a78951cae36e405eb531ba4d4732&quot;,
#                 {
#                     center: [0.0, 20.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fdc2b17e03052c60c00969f2747b24a7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fdc2b17e03052c60c00969f2747b24a7.addTo(map_cf64a78951cae36e405eb531ba4d4732);
#
#
#             var marker_bea9a086ae1ae3547569bd5fbb98d7ce = L.marker(
#                 [-30.5595, 22.9375],
#                 {
# }
#             ).addTo(map_cf64a78951cae36e405eb531ba4d4732);
#
#
#         var popup_e1b17f8023d7ed0e5aee0f643a43ba25 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_581ae1831ac241233ebe0fc7b534fd77 = $(`&lt;div id=&quot;html_581ae1831ac241233ebe0fc7b534fd77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;Company:&lt;/b&gt; Huntsman&lt;br&gt;         &lt;b&gt;Job Title:&lt;/b&gt; Accountant&lt;br&gt;         &lt;b&gt;Qualification:&lt;/b&gt; BA         &lt;/div&gt;`)[0];
#                 popup_e1b17f8023d7ed0e5aee0f643a43ba25.setContent(html_581ae1831ac241233ebe0fc7b534fd77);
#
#
#
#         marker_bea9a086ae1ae3547569bd5fbb98d7ce.bindPopup(popup_e1b17f8023d7ed0e5aee0f643a43ba25)
#         ;
#
#
#
#
#             marker_bea9a086ae1ae3547569bd5fbb98d7ce.bindTooltip(
#                 `&lt;div&gt;
#                      Click me
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_27002a38b84a74e5fb263e2dde7a7040 = L.marker(
#                 [-30.5595, 22.9375],
#                 {
# }
#             ).addTo(map_cf64a78951cae36e405eb531ba4d4732);
#
#
#         var popup_d687bca0970efb7e222b89710ac26939 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de50ba279a18a67f0b408746dd7ce998 = $(`&lt;div id=&quot;html_de50ba279a18a67f0b408746dd7ce998&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;Company:&lt;/b&gt; TD Ameritrade Holding Corporation&lt;br&gt;         &lt;b&gt;Job Title:&lt;/b&gt; Account Executive&lt;br&gt;         &lt;b&gt;Qualification:&lt;/b&gt; MCA         &lt;/div&gt;`)[0];
#                 popup_d687bca0970efb7e222b89710ac26939.setContent(html_de50ba279a18a67f0b408746dd7ce998);
#
#
#
#         marker_27002a38b84a74e5fb263e2dde7a7040.bindPopup(popup_d687bca0970efb7e222b89710ac26939)
#         ;
#
#
#
#
#             marker_27002a38b84a74e5fb263e2dde7a7040.bindTooltip(
#                 `&lt;div&gt;
#                      Click me
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_b123fe929a97992d592c1d6d72806914 = L.marker(
#                 [6.6111, 20.9394],
#                 {
# }
#             ).addTo(map_cf64a78951cae36e405eb531ba4d4732);
#
#
#         var popup_d5870259a529827c243a6418b7d2ce33 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aff21997e2c39c97e8f4ff0d18483d8d = $(`&lt;div id=&quot;html_aff21997e2c39c97e8f4ff0d18483d8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;Company:&lt;/b&gt; CDW&lt;br&gt;         &lt;b&gt;Job Title:&lt;/b&gt; UX/UI Designer&lt;br&gt;         &lt;b&gt;Qualification:&lt;/b&gt; MCA         &lt;/div&gt;`)[0];
#                 popup_d5870259a529827c243a6418b7d2ce33.setContent(html_aff21997e2c39c97e8f4ff0d18483d8d);
#
#
#
#         marker_b123fe929a97992d592c1d6d72806914.bindPopup(popup_d5870259a529827c243a6418b7d2ce33)
#         ;
#
#
#
#
#             marker_b123fe929a97992d592c1d6d72806914.bindTooltip(
#                 `&lt;div&gt;
#                      Click me
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_1c4e7b0c540f01a9d8656ae99b49c8a3 = L.marker(
#                 [-30.5595, 22.9375],
#                 {
# }
#             ).addTo(map_cf64a78951cae36e405eb531ba4d4732);
#
#
#         var popup_0d75f64ef82faaa92b6b73dae2f30049 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
